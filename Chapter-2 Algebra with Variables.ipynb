# %%
a = 3
a

# %%
type(a)

# %%
b = 4.2
print(b)
print(type(b))

# %%
print(a)
a*=2
print(a)
a-=1
print(a)
a+=4
print(a)

# %% [markdown]
# Keywords
# ![image.png](attachment:image.png)

# %% [markdown]
# Operations
# ![image.png](attachment:image.png)

# %%
# Complex Quantities.
e = 4+3j
print(e)
f = e*2
print(f)
# Out:
# (4+3j)
# (8+6j)

# %%
# Common Function with Number PG -22

# %% [markdown]
# # abs(-34.2)

# %%
h  = 2.1 - 4.3j
h*3
# Out:
# (6.300000000000001-12.899999999999999j)

# %%
complex(2.1, 4.3)
# Out:
# (2.1+4.3j)

# %%
pow(3,4)
# Out:
# 81

# %%
import math

# %%
math.sqrt(9)  # PG23
# Out:
# 3.0
